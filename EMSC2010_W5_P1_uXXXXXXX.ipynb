# %% [markdown]
# <a href="https://colab.research.google.com/github/dave-heslop74/EMSC2010-W5-P1/blob/main/EMSC2010_W5_P1_uXXXXXXX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W5-P1
#
# Use this notebook to perform your bootstrapping.
#
# Start by typing in your Alien Probe data set:

# %%
import numpy as np
X = np.array([1,0,1,1]) #change the values to your 25 data points

# %% [markdown]
# We can create bootstrap samples using the ```numpy``` function ```np.random.choice```.
